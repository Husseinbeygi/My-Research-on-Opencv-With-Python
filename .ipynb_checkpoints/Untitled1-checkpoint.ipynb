# %%
import numpy as np

# %%
ones = np.ones((5,5))

# %%
ones * 10
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
np.random.seed(101)
arr = np.random.randint(low = 0,high=100,size=(5,5))

# %%
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
arr.max()
# Out:
# 95

# %%
arr.min()
# Out:
# 4

# %%
import matplotlib.pyplot as plt
from PIL import Image as im

# %%
pic = im.open('/home/hussein/Pictures/1.jpg')

# %%
picarr = np.asarray(pic)

# %%
type(picarr)
# Out:
# numpy.ndarray

# %%
picarr.shape
# Out:
# (1280, 1064, 3)

# %%
plt.imshow(picarr[:,:,0])

# %%
plt.imshow(picarr[:,:,1])

# %%
plt.imshow(picarr[:,:,2])
