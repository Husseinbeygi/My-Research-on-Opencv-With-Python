# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image_show = cv2.cvtColor(cv2.imread("DATA/6.jpg"),cv2.COLOR_BGR2RGB)

# %%
image = cv2.imread("DATA/6.jpg")

# %%
hist_image = cv2.calcHist([image],[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_image)

# %%
color = ('b','g','r')

for i,col in enumerate(color):
    print(i)
    hist = cv2.calcHist([image],[i],mask=None,histSize=[256],ranges=[0,256])
    plt.plot(hist)
# Out:
# 0
# 1
# 2

# %%
eqhist = cv2.equalizeHist(image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-40-10129ccb89d5> in <module>
# ----> 1 eqhist = cv2.equalizeHist(image)
#
# error: OpenCV(3.4.2) /tmp/build/80754af9/opencv-suite_1535558553474/work/modules/imgproc/src/histogram.cpp:3334: error: (-215:Assertion failed) _src.type() == (((0) & ((1 << 3) - 1)) + (((1)-1) << 3)) in function 'equalizeHist'
